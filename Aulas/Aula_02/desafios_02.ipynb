# %% [markdown]
# # Desafios - Aula 02

# %% [markdown]
# ## Inicialização do Dataframe

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
url = "https://raw.githubusercontent.com/pedrogrigorio/Imersao-Dados-Alura/main/Materiais/dados_imoveis.csv"
dados = pd.read_csv(url)
dados
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10006         Rua Manuel Onha, , 514        Vila Oratório  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas  \
# 0          1000        4          8      6
# 1           496        4          4      4
# 2           125        4          3      2
# 3           310        3          2      4
# 4           100        3          2      2
# ...         ...      ...        ...    ...
# 10003        95        2          2      2
# 10004       605        8          7      5
# 10005       205        3          3      6
# 10006       185        3          2      2
# 10007       122        3          2      2
#
#                                       Valor
# 0                              R$ 7.000.000
# 1                              R$ 3.700.000
# 2                                R$ 380.000
# 3                                R$ 685.000
# 4                                R$ 540.000
# ...                                     ...
# 10003                            R$ 665.000
# 10004                          R$ 2.300.000
# 10005                          R$ 1.050.000
# 10006  R$ 2.200\n                      /Mês
# 10007                            R$ 270.000
#
# [10008 rows x 8 columns]

# %%
dados[["Moeda", "Valor_anuncio", "Tipo_anuncio"]] = dados["Valor"].str.split(expand = True)
dados_vendas = dados[dados["Tipo_anuncio"].isnull()]
dados_vendas["Valor_anuncio"] = dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)
dados_vendas
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_5012\2870325524.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados_vendas["Valor_anuncio"] = dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)
# C:\Users\pedro\AppData\Local\Temp\ipykernel_5012\2870325524.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_vendas["Valor_anuncio"] = dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda  Valor_anuncio  \
# 0          1000        4          8      6  R$ 7.000.000    R$      7000000.0
# 1           496        4          4      4  R$ 3.700.000    R$      3700000.0
# 2           125        4          3      2    R$ 380.000    R$       380000.0
# 3           310        3          2      4    R$ 685.000    R$       685000.0
# 4           100        3          2      2    R$ 540.000    R$       540000.0
# ...         ...      ...        ...    ...           ...   ...            ...
# 10002       267        3          6      4  R$ 1.500.000    R$      1500000.0
# 10003        95        2          2      2    R$ 665.000    R$       665000.0
# 10004       605        8          7      5  R$ 2.300.000    R$      2300000.0
# 10005       205        3          3      6  R$ 1.050.000    R$      1050000.0
# 10007       122        3          2      2    R$ 270.000    R$       270000.0
#
#       Tipo_anuncio
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# ...            ...
# 10002         None
# 10003         None
# 10004         None
# 10005         None
# 10007         None
#
# [9156 rows x 11 columns]

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Valor          9156 non-null   object
#  8   Moeda          9156 non-null   object
#  9   Valor_anuncio  9156 non-null   float64
#  10  Tipo_anuncio   0 non-null      object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 858.4+ KB

# %% [markdown]
# ## Desafio 01

# %% [markdown]
# ### Criar uma escala de valores em milhões.

# %% [markdown]
# Para isso, basta dividir os valores da coluna Valor_anuncio por 1 milhão e, em seguida, organizar pelo menor valor para saber qual precisão de casas decimais usar.

# %%
dados_vendas["Valor_anuncio"].sort_values().div(1000000).round(3)
# Out:
# 60       0.013
# 11       0.015
# 48       0.130
# 1596     0.147
# 2194     0.147
#          ...
# 3542    45.825
# 6131    55.000
# 6882    65.000
# 1530    65.000
# 400     65.000
# Name: Valor_anuncio, Length: 9156, dtype: float64

# %%
dados_vendas["Valor_em_milhão"] = dados_vendas["Valor_anuncio"].sort_values().div(1000000).round(3)
dados_vendas
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_5012\3212313836.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_vendas["Valor_em_milhão"] = dados_vendas["Valor_anuncio"].sort_values().div(1000000).round(3)
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda  Valor_anuncio  \
# 0          1000        4          8      6  R$ 7.000.000    R$      7000000.0
# 1           496        4          4      4  R$ 3.700.000    R$      3700000.0
# 2           125        4          3      2    R$ 380.000    R$       380000.0
# 3           310        3          2      4    R$ 685.000    R$       685000.0
# 4           100        3          2      2    R$ 540.000    R$       540000.0
# ...         ...      ...        ...    ...           ...   ...            ...
# 10002       267        3          6      4  R$ 1.500.000    R$      1500000.0
# 10003        95        2          2      2    R$ 665.000    R$       665000.0
# 10004       605        8          7      5  R$ 2.300.000    R$      2300000.0
# 10005       205        3          3      6  R$ 1.050.000    R$      1050000.0
# 10007       122        3          2      2    R$ 270.000    R$       270000.0
#
#       Tipo_anuncio  Valor_em_milhão
# 0             None            7.000
# 1             None            3.700
# 2             None            0.380
# 3             None            0.685
# 4             None            0.540
# ...            ...              ...
# 10002         None            1.500
# 10003         None            0.665
# 10004         None            2.300
# 10005         None            1.050
# 10007         None            0.270
#
# [9156 rows x 12 columns]

# %% [markdown]
# ## Desafio 02

# %% [markdown]
# ### Deixar o gráfico do histograma de valores legível (alterar labels, cores, título, escala).

# %% [markdown]
# Para a escala, podemos usar a criada no desafio anterior e a cor resolvi colocar verde escuro, para contrastar bem com o fundo claro. Além disso, a alteração de labels e título é feita com os comandos `set_title`, `set_xlabel` e `set_ylabel`.

# %%
sns.set()
plt.figure(figsize=(10,8))
ax = sns.histplot(data = dados_vendas, x = "Valor_em_milhão", color='darkgreen')
ax.set_title("Valores de Imóveis em São Paulo", size = 16)
ax.set_xlabel("Valor em Milhões", size = 14)
ax.set_ylabel("Quantidade de Imóveis", size = 14)
plt.xlim((-0.5, 20))
plt.show()

# %% [markdown]
# ## Desafio 03

# %% [markdown]
# ### Preço do metro quadrado por bairro e plotar em um gráfico ideal.

# %% [markdown]
# Basta criar uma outra coluna que receba o resultado da divisão da coluna Valor_anuncio pela coluna Metragem e depois tirar uma média por bairro.

# %%
dados_vendas["Valor_metro"] = dados_vendas["Valor_anuncio"] / dados_vendas["Metragem"]
dados_vendas.head()
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_5012\2643760688.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_vendas["Valor_metro"] = dados_vendas["Valor_anuncio"] / dados_vendas["Metragem"]
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda  Valor_anuncio Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000    R$      7000000.0         None
# 1        4          4      4  R$ 3.700.000    R$      3700000.0         None
# 2        4          3      2    R$ 380.000    R$       380000.0         None
# 3        3          2      4    R$ 685.000    R$       685000.0         None
# 4        3          2      2    R$ 540.000    R$       540000.0         None
#
#    Valor_em_milhão  Valor_metro
# 0            7.000  7000.000000
# 1            3.700  7459.677419
# 2            0.380  3040.000000
# 3            0.685  2209.677419
# 4            0.540  5400.000000

# %%
preco_metro_bairro = dados_vendas.groupby("Bairro")["Valor_metro"].mean()
preco_metro_bairro
# Out:
# Bairro
# Aclimação             7656.169465
# Alto da Boa Vista     5849.569011
# Alto da Lapa          7606.728080
# Alto da Mooca         5691.740133
# Alto de Pinheiros    11269.979971
#                          ...
# Vila Água Funda       4467.127995
# Água Branca           7269.113912
# Água Fria             5841.104428
# Água Funda            3876.862745
# Água Rasa             4509.608463
# Name: Valor_metro, Length: 697, dtype: float64

# %% [markdown]
# Criando um dataframe a partir da series.

# %%
df_preco_metro_bairro = pd.DataFrame(preco_metro_bairro, columns=['Valor_metro'])
df_preco_metro_bairro.sort_values("Valor_metro").round(2)
# Out:
#                               Valor_metro
# Bairro
# Sítio Represa                       78.38
# Jardim Vera Cruz(Zona Leste)       544.76
# Vila Aurea                         906.59
# Jardim Itapemirim                 1054.50
# Jardim Brasília (Zona Leste)      1055.01
# ...                                   ...
# Vila Nova Conceição              17614.03
# Jardim Europa                    19962.69
# Jardim Ampliação                 20051.04
# Jardim América                   24088.57
# Vila Guaca                       80000.00
#
# [697 rows x 1 columns]

# %% [markdown]
# Criando um dataframe para os 25 primeiros e os 25 últimos do dataframe acima.

# %%
df_25maiores = df_preco_metro_bairro.head(25).sort_values("Valor_metro",ascending = True).round(2)
df_25menores = df_preco_metro_bairro.tail(25).sort_values("Valor_metro",ascending = True).round(2)

# %% [markdown]
# Buscando algumas informações sobre os dataframes que acabamos de criar.

# %%
df_25maiores.describe()
# Out:
#         Valor_metro
# count     25.000000
# mean    6153.862000
# std     2497.028718
# min     1726.620000
# 25%     4457.900000
# 50%     6146.310000
# 75%     7264.920000
# max    12343.150000

# %%
df_25menores.describe()
# Out:
#        Valor_metro
# count    25.000000
# mean   4759.542400
# std    1768.230635
# min    2552.950000
# 25%    3666.670000
# 50%    4467.130000
# 75%    5456.150000
# max    9912.120000

# %% [markdown]
# Plotando os gráficos.

# %%
ax = sns.barplot(y=df_25maiores.index, x="Valor_metro", data=df_25maiores, orient="h")
ax.set_title("25 Maiores Valores de Metro por Bairro")
ax.set_xlabel("Valor do Metro")
ax.set_ylabel("Bairro")
plt.xlim((0, 13000))
plt.show()

# %%
ax = sns.barplot(y=df_25menores.index, x="Valor_metro", data=df_25menores, orient="h")
ax.set_title("25 Menores Valores de Metro por Bairro")
ax.set_xlabel("Valor do Metro")
ax.set_ylabel("Bairro")
plt.xlim((0, 13000))
plt.show()

# %% [markdown]
# ## Desafio 04

# %% [markdown]
# ### Explorar as bibliotecas de visualizações e colocar as suas conclusão.

# %% [markdown]
# ## Desafio 05

# %% [markdown]
# ### Pesquisar um visualização para analisar os quartis, mediana e outliers.
